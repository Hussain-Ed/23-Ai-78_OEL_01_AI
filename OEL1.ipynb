# %% [markdown]
# 🔹 Part 1: Data Handling with Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/shelter_data.csv')
df
# Out:
#   shelter_id     shelter_name  capacity
# 0         S1    Alpha Shelter       200
# 1         S2     Beta Shelter       150
# 2         S3    Delta Shelter       300
# 3         S4     Echo Shelter       100
# 4         S5  Foxtrot Shelter       250

# %%
df[df['capacity']<200]
# Out:
#   shelter_id  shelter_name  capacity
# 1         S2  Beta Shelter       150
# 3         S4  Echo Shelter       100

# %%
df[df['capacity'] == df['capacity'].max()]
# Out:
#   shelter_id   shelter_name  capacity
# 2         S3  Delta Shelter       300

# %% [markdown]
# 🔹 Part 2: Graph Representation

# %%
roads = {
 'S1': ['S2', 'S3'],
 'S2': ['S1', 'S4'],
 'S3': ['S1', 'S5'],
 'S4': ['S2'],
 'S5': ['S3']
}

print(roads)
# Out:
# {'S1': ['S2', 'S3'], 'S2': ['S1', 'S4'], 'S3': ['S1', 'S5'], 'S4': ['S2'], 'S5': ['S3']}

# %% [markdown]
# 🔹 Part 3: Implement BFS

# %%
import collections as cl

# %%
def BFS(roads, start):
  shelterID = set()
  queue = cl.deque()
  while queue:
    start = queue.popleft()
    if start not in shelterID:
      shelterID.add(start)
      roads.extend(roads[start])
  return shelterID

print(BFS(roads, 'S1'))
# Out:
# set()

# %% [markdown]
# 🔹 Bonus Task: Integrated Analysis

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df[df['capacity']>200])
plt.show()
